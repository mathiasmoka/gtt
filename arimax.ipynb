# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller

import matplotlib.pyplot as plt

# %%
df = charger_donnees()

df = ajouter_zones(df)

print(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = charger_donnees()
#       3 df = ajouter_zones(df)
#       5 print(df.head())
#
# NameError: name 'charger_donnees' is not defined
